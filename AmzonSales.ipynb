# %% [markdown]
# **Importing Required Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Importing the dataset**

# %%
sales_data= pd.read_csv('Amazon Sales data.csv')
sales_data
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
# checking the shape
sales_data.shape
# Out:
# (100, 14)

# %%
# Show columns present in dataframe
sales_data.columns
# Out:
# Index(['Region', 'Country', 'Item Type', 'Sales Channel', 'Order Priority',
#        'Order Date', 'Order ID', 'Ship Date', 'Units Sold', 'Unit Price',
#        'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit'],
#       dtype='object')

# %%
# Show basic information of dataframe
sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Region          100 non-null    object
#  1   Country         100 non-null    object
#  2   Item Type       100 non-null    object
#  3   Sales Channel   100 non-null    object
#  4   Order Priority  100 non-null    object
#  5   Order Date      100 non-null    object
#  6   Order ID        100 non-null    int64
#  7   Ship Date       100 non-null    object
#  8   Units Sold      100 non-null    int64
#  9   Unit Price      100 non-null    float64
#  10  Unit Cost       100 non-null    float64
#  11  Total Revenue   100 non-null    float64
#  12  Total Cost      100 non-null    float64
#  13  Total Profit    100 non-null    float64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 11.1+ KB

# %%
# Changing the data type of different column
sales_data['Order Date'] = pd.to_datetime(sales_data['Order Date'])
sales_data['Ship Date'] = pd.to_datetime(sales_data['Ship Date'])

# %%
sales_data['Region'] = sales_data['Region'].astype(str)
sales_data['Country'] = sales_data['Country'].astype(str)
sales_data['Item Type'] = sales_data['Item Type'].astype(str)
sales_data['Sales Channel'] = sales_data['Sales Channel'].astype(str)
sales_data['Order Priority'] = sales_data['Order Priority'].astype(str)

# %%
# Checking no. of Null Values
sales_data.isnull().sum()
# Out:
# Region            0
# Country           0
# Item Type         0
# Sales Channel     0
# Order Priority    0
# Order Date        0
# Order ID          0
# Ship Date         0
# Units Sold        0
# Unit Price        0
# Unit Cost         0
# Total Revenue     0
# Total Cost        0
# Total Profit      0
# dtype: int64

# %%
sales_data.describe()
# Out:
#                 Order Date      Order ID            Ship Date   Units Sold  \
# count                  100  1.000000e+02                  100   100.000000
# mean   2013-09-16 14:09:36  5.550204e+08  2013-10-09 22:48:00  5128.710000
# min    2010-02-02 00:00:00  1.146066e+08  2010-02-25 00:00:00   124.000000
# 25%    2012-02-14 12:00:00  3.389225e+08  2012-02-24 18:00:00  2836.250000
# 50%    2013-07-12 12:00:00  5.577086e+08  2013-08-11 12:00:00  5382.500000
# 75%    2015-04-07 00:00:00  7.907551e+08  2015-04-28 00:00:00  7369.000000
# max    2017-05-22 00:00:00  9.940222e+08  2017-06-17 00:00:00  9925.000000
# std                    NaN  2.606153e+08                  NaN  2794.484562
#
#        Unit Price   Unit Cost  Total Revenue    Total Cost  Total Profit
# count  100.000000  100.000000   1.000000e+02  1.000000e+02  1.000000e+02
# mean   276.761300  191.048000   1.373488e+06  9.318057e+05  4.416820e+05
# min      9.330000    6.920000   4.870260e+03  3.612240e+03  1.258020e+03
# ...

# %%
# Adding extra column to dataframe which contain only month, year and month with year
sales_data['Order Month'] = sales_data['Order Date'].dt.month
sales_data['Order Year'] = sales_data['Order Date'].dt.year
sales_data['Order Date MonthYear'] = sales_data['Order Date'].dt.strftime('%Y-%m')

# %%
sales_data.head()
# Out:
#                               Region                Country        Item Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub-Saharan Africa                 Rwanda  Office Supplies
#
#   Sales Channel Order Priority Order Date   Order ID  Ship Date  Units Sold  \
# 0       Offline              H 2010-05-28  669165933 2010-06-27        9925
# 1        Online              C 2012-08-22  963881480 2012-09-15        2804
# 2       Offline              L 2014-05-02  341417157 2014-05-08        1779
# 3        Online              C 2014-06-20  514321792 2014-07-05        8102
# 4       Offline              L 2013-02-01  115456712 2013-02-06        5062
#
# ...

# %%
#save this to csv file
sales_data.to_csv('Amazon Sales transformed data.csv', index=False)
print('data saved to csv')
# Out:
# data saved to csv

# %%
df=sales_data

# %% [markdown]
# **Exploratory Data Analysis**

# %%
#calculate the no of regions
regions= df['Region'].nunique()
regions
# Out:
# 7

# %%
#calculate no of Countries
countries= df['Country'].nunique()
countries
# Out:
# 76

# %%
#calculate the item types
item_types= df['Item Type'].nunique()
item_types
# Out:
# 12

# %%
#calculate the total unit sold
total_unit_sold= df['Units Sold'].sum()
total_unit_sold
# Out:
# 512871

# %%
#calculate the total unit cost
total_unit_cost= df['Unit Cost'].sum()
total_unit_cost
# Out:
# 19104.8

# %%
#calulate Total Revenue
total_revenue= df['Total Revenue'].sum()
total_revenue
# Out:
# 137348768.31

# %%
#calculate total cost
total_cost= df['Total Cost'].sum()
total_cost
# Out:
# 93180569.91000001

# %%
#calculate total profit
total_profit= df['Total Profit'].sum()
total_profit
# Out:
# 44168198.39999999

# %%
#groupby region,sales channel, total profit
df.groupby(['Region','Sales Channel'])['Total Profit'].sum()
# Out:
# Region                             Sales Channel
# Asia                               Offline          3584286.33
#                                    Online           2529559.54
# Australia and Oceania              Offline          1886283.82
#                                    Online           2835876.21
# Central America and the Caribbean  Offline          2475814.99
#                                    Online            371092.86
# Europe                             Offline          5574539.91
#                                    Online           5508398.72
# Middle East and North Africa       Offline          2169081.08
#                                    Online           3592110.78
# North America                      Offline          1457942.76
# Sub-Saharan Africa                 Offline          7772777.78
#                                    Online           4410433.62
# Name: Total Profit, dtype: float64

# %%
#year wise sales
Year_sales= df.groupby('Order Year')['Total Revenue'].mean()
plt.figure(figsize=(8,3))
sns.barplot(x=Year_sales.index,y=Year_sales.values)
plt.title('Average sales by Year')
plt.xlabel('Year')
plt.ylabel('total revenue')
plt.xticks(rotation=90)
plt.show()

# %%
#pie chart of total profit in region wise
plt.figure(figsize=(6,6))
region_TotalRevenue= df.groupby('Region')['Total Revenue'].mean()
plt.pie(region_TotalRevenue,labels=region_TotalRevenue.index,autopct='%1.1f%%')
plt.title('Average profit in region wise')
plt.show()

# %%
#groupby Total revenue by item types
TotalRevenue_ItemTypes=df.groupby('Item Type')['Total Revenue'].sum()

# %%
#bar chart for Total Revenue by Item types
plt.figure(figsize=(6,4))
TotalRevenue_ItemTypes.plot(kind='bar')
plt.title('Total Revenue by Item Types')
plt.xlabel('Item Types')
plt.ylabel('Total Revenue')
plt.show()

# %%
#group total revenue by sales channel
TotalRevenue_SalesChannel=df.groupby('Sales Channel')['Total Revenue'].mean()

# %%
#pie chart for total revenue by sales channel
plt.figure(figsize=(6,6))
plt.pie(TotalRevenue_SalesChannel,labels=TotalRevenue_SalesChannel.index,autopct='%1.1f%%')
plt.title('Total Revenue by Sales Channel')
plt.show()

# %%
#donut chart for Region wise unit sold
plt.figure(figsize=(6,6))
Region_UnitsSold=df.groupby('Region')['Units Sold'].sum()
plt.pie(Region_UnitsSold,labels=Region_UnitsSold.index,autopct='%1.1f%%')

#create a donut chart using pie chart
my_circle=plt.Circle( (0,0), 0.7, color='white')
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.title('Region wise Unit sold')
plt.show()

# %%
#first groupby units sold by year and month then create a bar chart for units sold by year and month
UnitsSold_YearMonth=df.groupby(['Order Year','Order Month'])['Units Sold'].sum()
plt.figure(figsize=(10,4))
UnitsSold_YearMonth.plot(kind='bar')
plt.title('Units Sold by Year and Month')
plt.xlabel('Year and Month')
plt.ylabel('Units Sold')
plt.tight_layout()
plt.show()

# %%
#total cost by sales chennel
TotalCost_SalesChannel=df.groupby('Sales Channel')['Total Cost'].sum()
#pie chart for total cost by sales chennel
plt.figure(figsize=(6,6))
plt.pie(TotalCost_SalesChannel,labels=TotalCost_SalesChannel.index,autopct='%1.1f%%')
plt.title('Total Cost by Sales Channel')
plt.show()
